# %%
import pandas as pd
import re
import os

# %%
large_df = pd.read_csv('../DAOU/test_large_out_v3.csv', index_col=0, encoding='euc-kr')

# %%
large_df.head()
# Out:
#                  사업장명  업소유형    업태구분명                      지번주소  \
# 0            어반스테이 명동  레지던스  숙박업(생활)        서울특별시 중구 인현동1가 158
# 1           오요5(oYo5)   호스텔     관광호텔       서울특별시 중구 남산동2가 35-2
# 2           더스테이클래식호텔    호텔  숙박업(생활)        서울특별시 중구 남대문로3가 94
# 3  오요5롯지A(oYo5LodgeA)   NaN   숙박업 기타  서울특별시 중구 남산동2가 33-3 1~2층
# 4  오요5롯지B(oYo5LodgeB)   NaN     관광호텔    서울특별시 중구 남산동2가 33 1,2층
#
#                                   도로명주소   가까운 지하철역   지하철역과의 거리      도보시간  \
# 0        서울특별시 중구 충무로 24, 3~17층 (인현동1가)        충무로  223.010258  3.343482
# 1  서울특별시 중구 퇴계로18길 43, 지층, 1~2층 (남산동2가)         명동  263.215774  3.946263
# 2             서울특별시 중구 남대문로 27 (남대문로3가)  회현(남대문시장)  330.151983  4.949805
# 3      서울특별시 중구 퇴계로18길 41 (남산동2가, 1~2층)         명동  240.223310  3.601549
# 4      서울특별시 중구 퇴계로18길 37 (남산동2가, 1,2층)         명동  226.602301  3.397336
#
#           위도          경도  ...  네이버 이런점이 좋아요 총합  \
# 0  37.563358  126.993360  ...             41.0
# 1  37.558934  126.984838  ...              NaN
# ...
